# %%
import os
import sys
import datetime
import time
import re
import pandas as pd
import pandasdmx
from plotnine import ggplot
import matplotlib as mpl
import matplotlib.pyplot as plt
print("Python version= {0}".format(sys.version_info))
print("Pandas version= {0}".format(pd.__version__))
print("Datetime= {0}".format(datetime.datetime.now()))
# Out:
# C:\Users\John\anaconda3\envs\payems\lib\site-packages\pandasdmx\remote.py:10: RuntimeWarning: optional dependency requests_cache is not installed; cache options to Session() have no effect
#   warn(
# Python version= sys.version_info(major=3, minor=8, micro=5, releaselevel='final', serial=0)
# Pandas version= 1.1.3
# Datetime= 2020-10-18 11:13:46.343024

# %%
from cif import cif
country = 'USA'

# %%
data_all, subjects_all, measures_all = cif.createDataFrameFromOECD(countries = [country], dsname = 'MEI', frequency = 'M')
# Out:
# Requesting URL http://stats.oecd.org/SDMX-JSON/data/MEI/USA...M/all
# Data downloaded from https://stats.oecd.org/SDMX-JSON/data/MEI/USA...M/all?dimensionAtObservation=AllDimensions

# %%
#pd.display.max_colwidth = 90
pd.set_option('display.max_colwidth', 1000)
df = subjects_all
#subjects_all.loc[barr]
df[df['name'].str.contains('onf')]
#df['name'][10:30]
# Out:
#           id                                                                                                           name
# 22  BSCICP02  Business tendency surveys (manufacturing) > Confidence indicators > Composite indicators > National indicator
# 23  CSCICP02                   Consumer opinion surveys > Confidence indicators > Composite indicators > National indicator
# 26  CSCICP03                       Consumer opinion surveys > Confidence indicators > Composite indicators > OECD Indicator
# 29  BSCICP03      Business tendency surveys (manufacturing) > Confidence indicators > Composite indicators > OECD Indicator
# 63  LOCOCINO                            Leading Indicators OECD > Component series > CS - Confidence indicator > Normalised
# 64  LOCOCIOR                       Leading Indicators OECD > Component series > CS - Confidence indicator > Original series

# %%
oecd = pandasdmx.Request('OECD')
data_response = oecd.data(resource_id='MEI_CLI', key={'GEO':'US'}, dry_run=True) # #key='all?startTime=2018')
data_response
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-4f5b7315fd1d> in <module>
#       1 oecd = pandasdmx.Request('OECD')
# ----> 2 data_response = oecd.data(resource_id='MEI_CLI', key={'GEO':'US'}, dry_run=True) # #key='all?startTime=2018')
#       3 data_response
#
# ~\anaconda3\envs\payems\lib\site-packages\pandasdmx\api.py in get(self, resource_type, resource_id, tofile, use_cache, dry_run, **kwargs)
#     394         else:
#     395             kwargs.update(dict(resource_type=resource_type, resource_id=resource_id))
# --> 396             req = self._request_from_args(kwargs)
#     397
#     398         req = self.session.prepare_request(req)
#
# ~\anaconda3\envs\payems\lib\site-packages\pandasdmx\api.py in _request_from_args(self, kwargs)
#     225         if validate:
#     226             # Make the key, and retain the DSD (if any) for use in parsing
# --> 227             key, dsd = self._make_key(resource_type, resource_id, key, dsd)
#     228             kwargs["dsd"] = dsd
#     229
#
# ~\anaconda3\envs\payems\lib\site-packages\pandasdmx\api.py in _make_key(self, resource_type, resource_id, key, dsd)
#     145         else:
#     146             # Construct a DSD from the keys
# --> 147             dsd = DataStructureDefinition.from_keys(self.series_keys(resource_id))
#     148
#     149         # Make a ContentConstraint from the key
#
# ~\anaconda3\envs\payems\lib\site-packages\pandasdmx\api.py in series_keys(self, flow_id, use_cache)
#     110         # download an empty dataset with all available series keys
#     111         return (
# --> 112             self.data(flow_id, params={"detail": "serieskeysonly"}, use_cache=use_cache)
#     113             .data[0]
#     114             .series.keys()
#
# ~\anaconda3\envs\payems\lib\site-packages\pandasdmx\api.py in get(self, resource_type, resource_id, tofile, use_cache, dry_run, **kwargs)
#     451
#     452         # Parse the message, using any provided or auto-queried DSD
# --> 453         msg = reader.read_message(response_content, dsd=kwargs.get("dsd", None))
#     454
#     455         # Store the HTTP response with the message
#
# ~\anaconda3\envs\payems\lib\site-packages\pandasdmx\reader\sdmxjson.py in read_message(self, source, dsd)
#      94         self._attr_level = dict()
#      95         self._attr_values = dict()
# ---> 96         for level_name, level in structure["attributes"].items():
#      97             for attr in level:
#      98                 # Create a DataAttribute in the DSD
#
# KeyError: 'attributes'

# %%
data_response.data[0].series
len(data_response.data[0].series)
dir(data_response)
df = data_response.to_pandas()

# %%
df.head()
df.shape
# Out:
# (14163,)
