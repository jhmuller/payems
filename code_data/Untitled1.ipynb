# %%
def fib_recursive(n):
    if n <= 0:
        print("n must be >0")
    if n == 1:
        return 0
    if n == 2:
        return 1
    return fib_recursive(n-1) + fib_recursive(n-2)



def print_fib(n):
    fib = fib_recursive
    for i in range(1,n+1):
        print(fib(i))

def print_fib2(n):
    if n
        
print_fib(5)
# Out:
# 0
# 1
# 1
# 2
# 3
